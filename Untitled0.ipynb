# %%
# Install the Kaggle API client
# !pip install kaggle
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.12/dist-packages (2.0.2)
# Requirement already satisfied: bleach in /usr/local/lib/python3.12/dist-packages (from kaggle) (6.4.0)
# Requirement already satisfied: jupytext in /usr/local/lib/python3.12/dist-packages (from kaggle) (1.19.3)
# Requirement already satisfied: kagglesdk<1.0,>=0.1.20 in /usr/local/lib/python3.12/dist-packages (from kaggle) (0.1.23)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from kaggle) (26.2)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from kaggle) (5.29.6)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.12/dist-packages (from kaggle) (2.9.0.post0)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.12/dist-packages (from kaggle) (8.0.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from kaggle) (2.32.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from kaggle) (4.67.3)
# Requirement already satisfied: urllib3>=1.15.1 in /usr/local/lib/python3.12/dist-packages (from kaggle) (2.5.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.12/dist-packages (from bleach->kaggle) (0.5.1)
# Requirement already satisfied: markdown-it-py>=1.0 in /usr/local/lib/python3.12/dist-packages (from jupytext->kaggle) (4.2.0)
# Requirement already satisfied: mdit-py-plugins in /usr/local/lib/python3.12/dist-packages (from jupytext->kaggle) (0.6.1)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.12/dist-packages (from jupytext->kaggle) (5.10.4)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from jupytext->kaggle) (6.0.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil->kaggle) (1.17.0)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.12/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->kaggle) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->kaggle) (3.18)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->kaggle) (2026.5.20)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=1.0->jupytext->kaggle) (0.1.2)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.12/dist-packages (from nbformat->jupytext->kaggle) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.12/dist-packages (from nbformat->jupytext->kaggle) (4.26.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /usr/local/lib/python3.12/dist-packages (from nbformat->jupytext->kaggle) (5.9.1)
# Requirement already satisfied: traitlets>=5.1 in /usr/local/lib/python3.12/dist-packages (from nbformat->jupytext->kaggle) (5.7.1)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->jupytext->kaggle) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->jupytext->kaggle) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->jupytext->kaggle) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->jupytext->kaggle) (2026.5.1)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.12/dist-packages (from jupyter-core!=5.0.*,>=4.12->nbformat->jupytext->kaggle) (4.10.0)
# Requirement already satisfied: typing-extensions>=4.4.0 in /usr/local/lib/python3.12/dist-packages (from referencing>=0.28.4->jsonschema>=2.6->nbformat->jupytext->kaggle) (4.15.0)

# %%
import os
import json

# Your Kaggle username
KAGGLE_USERNAME = 'mariamkapanadze'
# Your Kaggle API key (provided in previous context)
KAGGLE_API_KEY = 'KGAT_50dfc0cd14d716963419e195a5dce230'

# Create the .kaggle directory if it doesn't exist
kaggle_dir = os.path.expanduser('~/.kaggle')
os.makedirs(kaggle_dir, exist_ok=True);

# Create kaggle.json file
kaggle_json_path = os.path.join(kaggle_dir, 'kaggle.json')
kaggle_config = {"username": KAGGLE_USERNAME, "key": KAGGLE_API_KEY}

with open(kaggle_json_path, 'w') as f:
    json.dump(kaggle_config, f)

# Set permissions for the kaggle.json file
os.chmod(kaggle_json_path, 0o600)

print("Kaggle API key configured successfully!")
# Out:
# Kaggle API key configured successfully!

# %%
# Download data for the 'Challenges in Representation Learning: Facial Expression Recognition Challenge'
# !kaggle competitions download -c 'challenges-in-representation-learning-facial-expression-recognition-challenge'

# You might also want to unzip the downloaded files
# import zipfile
# with zipfile.ZipFile('challenges-in-representation-learning-facial-expression-recognition-challenge.zip', 'r') as zip_ref:
#     zip_ref.extractall('./fer2013') # Extract to a new directory named fer2013
# !cat ~/.kaggle/kaggle.json
# Out:
# 401 Client Error: Unauthorized for url: https://api.kaggle.com/v1/competitions.CompetitionApiService/DownloadDataFiles
# {"username": "mariamkapanadze", "key": "KGAT_50dfc0cd14d716963419e195a5dce230"}

# %%
# !pip install -q kagglehub

# %%
import kagglehub
kagglehub.login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://www.kaggle.com/static/images/site-logo.png\nalt=\'Kaggle…
# Kaggle credentials set.
# Kaggle credentials successfully validated.

# %%
path = kagglehub.competition_download(
    "challenges-in-representation-learning-facial-expression-recognition-challenge"
)

print(path)
# Out:
# Downloading to /root/.cache/kagglehub/competitions/challenges-in-representation-learning-facial-expression-recognition-challenge.archive...
# 100%|██████████| 285M/285M [00:14<00:00, 20.5MB/s]
# Extracting files...
# /root/.cache/kagglehub/competitions/challenges-in-representation-learning-facial-expression-recognition-challenge

# %%
import os

path = "/root/.cache/kagglehub/competitions/challenges-in-representation-learning-facial-expression-recognition-challenge"

print(os.listdir(path))
# Out:
# ['icml_face_data.csv', 'test.csv', 'fer2013.tar.gz', 'train.csv', 'example_submission.csv']

# %%
import os
import numpy as np
import pandas as pd
import torch
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as transforms

path = "/root/.cache/kagglehub/competitions/challenges-in-representation-learning-facial-expression-recognition-challenge"
train_df = pd.read_csv(os.path.join(path, 'train.csv'))
class FERDataset(Dataset):
    def __init__(self, df, transform=None):
        self.df = df
        self.transform = transform

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        row = self.df.iloc[idx]
        pixels = np.fromstring(row['pixels'], dtype=np.uint8, sep=' ')
        image = pixels.reshape(48, 48)

        label = int(row['emotion'])

        if self.transform:
            image = self.transform(image)

        return image, label
base_transform = transforms.Compose([
    transforms.ToPILImage(),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5], std=[0.5])
])

dataset = FERDataset(train_df, transform=base_transform)
train_size = int(0.8 * len(dataset))
val_size = len(dataset) - train_size
train_set, val_set = torch.utils.data.random_split(dataset, [train_size, val_size])

train_loader = DataLoader(train_set, batch_size=64, shuffle=True)
val_loader = DataLoader(val_set, batch_size=64, shuffle=False)

# %% [markdown]
# დავაკავშიროთ WandB

# %%
# !pip install wandb
# Out:
# Requirement already satisfied: wandb in /usr/local/lib/python3.12/dist-packages (0.27.2)
# Requirement already satisfied: click>=8.2.0 in /usr/local/lib/python3.12/dist-packages (from wandb) (8.4.1)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb) (3.1.50)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from wandb) (26.2)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.12/dist-packages (from wandb) (4.10.0)
# Requirement already satisfied: protobuf!=5.28.0,!=5.29.0,<8,>4.21.0 in /usr/local/lib/python3.12/dist-packages (from wandb) (5.29.6)
# Requirement already satisfied: pydantic<3,>=2.6 in /usr/local/lib/python3.12/dist-packages (from wandb) (2.12.3)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from wandb) (6.0.3)
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb) (2.32.4)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb) (2.62.0)
# Requirement already satisfied: typing-extensions<5,>=4.8 in /usr/local/lib/python3.12/dist-packages (from wandb) (4.15.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from gitpython!=3.1.29,>=1.0.0->wandb) (4.0.12)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=2.6->wandb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=2.6->wandb) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=2.6->wandb) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0.0->wandb) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0.0->wandb) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0.0->wandb) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0.0->wandb) (2026.5.20)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb) (5.0.3)

# %%
import wandb; wandb.login()
# Out:
# /usr/local/lib/python3.12/dist-packages/notebook/notebookapp.py:191: SyntaxWarning: invalid escape sequence '\/'
#   | |_| | '_ \/ _` / _` |  _/ -_)
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: 2
# wandb: You chose 'Use an existing W&B account'
# wandb: Logging into https://api.wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: Create a new API key at: https://wandb.ai/authorize?ref=models
# wandb: Store your API key securely and do not share it.
# wandb: Paste your API key and hit enter: ··········
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: mkapa22 (mkapa22-free-university-of-tbilisi-) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# True

# %%
wandb.init(
    project="facial-expression-recognition",
    name="baseline_small_cnn",
    config={
        "learning_rate": 0.001,
        "architecture": "Small-CNN",
        "dataset": "FER2013",
        "epochs": 10,
        "batch_size": 64
    }
)
# Out:
# Tracking run with wandb version 0.27.2
# Run data is saved locally in <code>/content/wandb/run-20260616_091534-1ivcwsmq</code>
# Syncing run <strong><a href='https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition/runs/1ivcwsmq' target="_blank">baseline_small_cnn</a></strong> to <a href='https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition' target="_blank">https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition</a>
#  View run at <a href='https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition/runs/1ivcwsmq' target="_blank">https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition/runs/1ivcwsmq</a>
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src='https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition/runs/1ivcwsmq?jupyter=true' style='border:none;width:100%;height:420px;display:none;'></iframe>

# %% [markdown]
# Sanity Check here. შევამოწმოთ Single Batch Overfitting სტრატეგია ძალიან მარტივ ქსელზე, რათა დავამტკიცოთ, რომ კოდში ბაგები არ გვაქვს.

# %%
import torch.nn as nn
class SmallCNN(nn.Module):
    def __init__(self):
        super().__init__()
        self.features = nn.Sequential(
            nn.Conv2d(1, 16, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2, 2), # 48x48 -> 24x24
            nn.Conv2d(16, 32, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2, 2)  # 24x24 -> 12x12
        )
        self.classifier = nn.Linear(32 * 12 * 12, 7) # 7 კლასი (ემოცია)

    def forward(self, x):
        return self.classifier(self.features(x).view(x.size(0), -1))

# %%
class DeepCNN(nn.Module):
    def __init__(self):
        super().__init__()
        self.features = nn.Sequential(
            nn.Conv2d(1, 32, kernel_size=3, padding=1), nn.ReLU(),
            nn.Conv2d(32, 64, kernel_size=3, padding=1), nn.ReLU(),
            nn.MaxPool2d(2, 2), # 24x24

            nn.Conv2d(64, 128, kernel_size=3, padding=1), nn.ReLU(),
            nn.Conv2d(128, 128, kernel_size=3, padding=1), nn.ReLU(),
            nn.MaxPool2d(2, 2)  # 12x12
        )
        self.classifier = nn.Sequential(
            nn.Linear(128 * 12 * 12, 256),
            nn.ReLU(),
            nn.Linear(256, 7)
        )

    def forward(self, x):
        return self.classifier(self.features(x).view(x.size(0), -1))

# %%
class OptCNN(nn.Module):
    def __init__(self):
        super().__init__()
        self.features = nn.Sequential(
            nn.Conv2d(1, 32, kernel_size=3, padding=1),
            nn.BatchNorm2d(32), nn.ReLU(),
            nn.MaxPool2d(2, 2), # 24x24
            nn.Dropout(0.25),

            nn.Conv2d(32, 64, kernel_size=3, padding=1),
            nn.BatchNorm2d(64), nn.ReLU(),
            nn.MaxPool2d(2, 2), # 12x12
            nn.Dropout(0.25),

            nn.Conv2d(64, 128, kernel_size=3, padding=1),
            nn.BatchNorm2d(128), nn.ReLU(),
            nn.MaxPool2d(2, 2), # 6x6
            nn.Dropout(0.4)
        )
        self.classifier = nn.Sequential(
            nn.Linear(128 * 6 * 6, 256),
            nn.BatchNorm1d(256), nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(256, 7)
        )

    def forward(self, x):
        return self.classifier(self.features(x).view(x.size(0), -1))

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
import wandb

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

def run_experiment(model_class, model_name, exp_name, lr=0.001, batch_size=64, weight_decay=0.0):
    #ინიციალიზაცია
    wandb.init(
        project="facial-expression-recognition",
        name=f"{model_name}_{exp_name}",
        config={
            "model_architecture": model_name,
            "experiment_type": exp_name,
            "learning_rate": lr,
            "batch_size": batch_size,
            "weight_decay": weight_decay,
            "epochs": 10
        }
    )

    # DataLoader-ის ხელახალი შექმნა
    train_loader = DataLoader(train_set, batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(val_set, batch_size=batch_size, shuffle=False)

    model = model_class().to(device)
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)

    epochs = 10
    print(f"\n starting: {model_name} | experiment: {exp_name}")
    print(f"Configs: LR={lr}, Batch Size={batch_size}, Weight Decay={weight_decay}")

    for epoch in range(epochs):
        # trainind
        model.train()
        running_loss, correct, total = 0.0, 0, 0
        for images, labels in train_loader:
            images, labels = images.to(device), labels.to(device)

            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item() * images.size(0)
            _, predicted = outputs.max(1)
            total += labels.size(0)
            correct += predicted.eq(labels).sum().item()

        train_loss = running_loss / len(train_set)
        train_acc = 100.0 * correct / total

        # validaciis nawili
        model.eval()
        val_loss, val_correct, val_total = 0.0, 0, 0
        with torch.no_grad():
            for images, labels in val_loader:
                images, labels = images.to(device), labels.to(device)
                outputs = model(images)
                loss = criterion(outputs, labels)

                val_loss += loss.item() * images.size(0)
                _, predicted = outputs.max(1)
                val_total += labels.size(0)
                val_correct += predicted.eq(labels).sum().item()

        valid_loss = val_loss / len(val_set)
        val_acc = 100.0 * val_correct / val_total

        print(f"Epoch {epoch+1:02d} -> Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.2f}% | Val Loss: {valid_loss:.4f}, Val Acc: {val_acc:.2f}%")

        wandb.log({
            "epoch": epoch + 1,
            "train_loss": train_loss,
            "train_acc": train_acc,
            "val_loss": valid_loss,
            "val_acc": val_acc
        })

    wandb.finish()
    print(f"✅ {model_name}_{exp_name} finished and logged\n")

# %% [markdown]
# experiment 1: baseline

# %%
run_experiment(SmallCNN, "SmallCNN", "Baseline", lr=0.001, batch_size=64)
# Out:
# Finishing previous runs because reinit is set to 'default'.
#  View run <strong style="color:#cdcd00">baseline_small_cnn</strong> at: <a href='https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition/runs/1ivcwsmq' target="_blank">https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition/runs/1ivcwsmq</a><br> View project at: <a href='https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition' target="_blank">https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260616_091534-1ivcwsmq/logs</code>
# Tracking run with wandb version 0.27.2
# Run data is saved locally in <code>/content/wandb/run-20260616_091543-61r9kf3m</code>
# Syncing run <strong><a href='https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition/runs/61r9kf3m' target="_blank">SmallCNN_Baseline</a></strong> to <a href='https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition' target="_blank">https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition</a>
#  View run at <a href='https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition/runs/61r9kf3m' target="_blank">https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition/runs/61r9kf3m</a>
#  starting: SmallCNN | experiment: Baseline
# Configs: LR=0.001, Batch Size=64, Weight Decay=0.0
# Epoch 01 -> Train Loss: 1.6311, Train Acc: 36.10% | Val Loss: 1.5110, Val Acc: 41.94%
# Epoch 02 -> Train Loss: 1.4324, Train Acc: 45.70% | Val Loss: 1.4320, Val Acc: 45.07%
# Epoch 03 -> Train Loss: 1.3336, Train Acc: 49.70% | Val Loss: 1.3873, Val Acc: 47.89%
# Epoch 04 -> Train Loss: 1.2667, Train Acc: 52.95% | Val Loss: 1.3655, Val Acc: 48.43%
# Epoch 05 -> Train Loss: 1.2129, Train Acc: 54.85% | Val Loss: 1.3542, Val Acc: 49.74%
# Epoch 06 -> Train Loss: 1.1574, Train Acc: 57.38% | Val Loss: 1.3590, Val Acc: 49.08%
# Epoch 07 -> Train Loss: 1.1071, Train Acc: 58.95% | Val Loss: 1.3756, Val Acc: 49.88%
# Epoch 08 -> Train Loss: 1.0658, Train Acc: 60.68% | Val Loss: 1.3671, Val Acc: 50.09%
# Epoch 09 -> Train Loss: 1.0221, Train Acc: 62.42% | Val Loss: 1.3838, Val Acc: 50.23%
# Epoch 10 -> Train Loss: 0.9850, Train Acc: 64.11% | Val Loss: 1.4050, Val Acc: 50.12%
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>train_acc</td><td>▁▃▄▅▆▆▇▇██</td></tr><tr><td>train_loss</td><td>█▆▅▄▃▃▂▂▁▁</td></tr><tr><td>val_acc</td><td>▁▄▆▆█▇████</td></tr><tr><td>val_loss</td><td>█▄▂▂▁▁▂▂▂▃</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>train_acc</td><td>64.10502</td></tr><tr><td>train_loss</td><td>0.98496</td></tr><tr><td>val_acc</td><td>50.12191</td></tr><tr><td>val_loss</td><td>1.40497</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">SmallCNN_Baseline</strong> at: <a href='https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition/runs/61r9kf3m' target="_blank">https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition/runs/61r9kf3m</a><br> View project at: <a href='https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition' target="_blank">https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260616_091543-61r9kf3m/logs</code>
# ✅ SmallCNN_Baseline finished and logged

# %% [markdown]
# experiment 1.2: high learning rate underfittingis სანახავად

# %%
run_experiment(SmallCNN, "SmallCNN", "High_LR", lr=0.01, batch_size=64)
# Out:
# Tracking run with wandb version 0.27.2
# Run data is saved locally in <code>/content/wandb/run-20260616_092046-vev2v7mf</code>
# Syncing run <strong><a href='https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition/runs/vev2v7mf' target="_blank">SmallCNN_High_LR</a></strong> to <a href='https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition' target="_blank">https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition</a>
#  View run at <a href='https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition/runs/vev2v7mf' target="_blank">https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition/runs/vev2v7mf</a>
#  starting: SmallCNN | experiment: High_LR
# Configs: LR=0.01, Batch Size=64, Weight Decay=0.0
# Epoch 01 -> Train Loss: 1.8425, Train Acc: 24.93% | Val Loss: 1.8064, Val Acc: 25.55%
# Epoch 02 -> Train Loss: 1.8120, Train Acc: 25.03% | Val Loss: 1.8046, Val Acc: 25.55%
# Epoch 03 -> Train Loss: 1.8118, Train Acc: 25.03% | Val Loss: 1.8042, Val Acc: 25.55%
# Epoch 04 -> Train Loss: 1.8117, Train Acc: 25.03% | Val Loss: 1.8051, Val Acc: 25.55%
# Epoch 05 -> Train Loss: 1.8117, Train Acc: 25.03% | Val Loss: 1.8047, Val Acc: 25.55%
# Epoch 06 -> Train Loss: 1.8120, Train Acc: 25.03% | Val Loss: 1.8048, Val Acc: 25.55%
# Epoch 07 -> Train Loss: 1.8118, Train Acc: 25.03% | Val Loss: 1.8052, Val Acc: 25.55%
# Epoch 08 -> Train Loss: 1.8119, Train Acc: 25.03% | Val Loss: 1.8060, Val Acc: 25.55%
# Epoch 09 -> Train Loss: 1.8119, Train Acc: 25.03% | Val Loss: 1.8047, Val Acc: 25.55%
# Epoch 10 -> Train Loss: 1.8116, Train Acc: 25.03% | Val Loss: 1.8062, Val Acc: 25.55%
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>train_acc</td><td>▁█████████</td></tr><tr><td>train_loss</td><td>█▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_acc</td><td>▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▂▁▄▃▃▄▇▃▇</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>train_acc</td><td>25.02721</td></tr><tr><td>train_loss</td><td>1.81165</td></tr><tr><td>val_acc</td><td>25.54859</td></tr><tr><td>val_loss</td><td>1.80625</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">SmallCNN_High_LR</strong> at: <a href='https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition/runs/vev2v7mf' target="_blank">https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition/runs/vev2v7mf</a><br> View project at: <a href='https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition' target="_blank">https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260616_092046-vev2v7mf/logs</code>
# ✅ SmallCNN_High_LR finished and logged

# %% [markdown]
# experiment 1.3 : small batch + regularization

# %%
run_experiment(SmallCNN, "SmallCNN", "Small_Batch_WD", lr=0.001, batch_size=32, weight_decay=1e-4)
# Out:
# Tracking run with wandb version 0.27.2
# Run data is saved locally in <code>/content/wandb/run-20260616_092346-bs621ja2</code>
# Syncing run <strong><a href='https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition/runs/bs621ja2' target="_blank">SmallCNN_Small_Batch_WD</a></strong> to <a href='https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition' target="_blank">https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition</a>
#  View run at <a href='https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition/runs/bs621ja2' target="_blank">https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition/runs/bs621ja2</a>
#  starting: SmallCNN | experiment: Small_Batch_WD
# Configs: LR=0.001, Batch Size=32, Weight Decay=0.0001
# Epoch 01 -> Train Loss: 1.6029, Train Acc: 37.82% | Val Loss: 1.4966, Val Acc: 42.49%
# Epoch 02 -> Train Loss: 1.3987, Train Acc: 46.95% | Val Loss: 1.4039, Val Acc: 46.10%
# Epoch 03 -> Train Loss: 1.2951, Train Acc: 51.71% | Val Loss: 1.3738, Val Acc: 47.91%
# Epoch 04 -> Train Loss: 1.2184, Train Acc: 54.57% | Val Loss: 1.3457, Val Acc: 49.76%
# Epoch 05 -> Train Loss: 1.1568, Train Acc: 57.31% | Val Loss: 1.3451, Val Acc: 49.60%
# Epoch 06 -> Train Loss: 1.1036, Train Acc: 59.42% | Val Loss: 1.3918, Val Acc: 49.48%
# Epoch 07 -> Train Loss: 1.0575, Train Acc: 61.14% | Val Loss: 1.3492, Val Acc: 50.17%
# Epoch 08 -> Train Loss: 1.0214, Train Acc: 62.66% | Val Loss: 1.3729, Val Acc: 50.82%
# Epoch 09 -> Train Loss: 0.9817, Train Acc: 63.96% | Val Loss: 1.3936, Val Acc: 50.66%
# Epoch 10 -> Train Loss: 0.9446, Train Acc: 65.41% | Val Loss: 1.4303, Val Acc: 50.09%
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>train_acc</td><td>▁▃▅▅▆▆▇▇██</td></tr><tr><td>train_loss</td><td>█▆▅▄▃▃▂▂▁▁</td></tr><tr><td>val_acc</td><td>▁▄▆▇▇▇▇██▇</td></tr><tr><td>val_loss</td><td>█▄▂▁▁▃▁▂▃▅</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>train_acc</td><td>65.40689</td></tr><tr><td>train_loss</td><td>0.94464</td></tr><tr><td>val_acc</td><td>50.08708</td></tr><tr><td>val_loss</td><td>1.43025</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">SmallCNN_Small_Batch_WD</strong> at: <a href='https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition/runs/bs621ja2' target="_blank">https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition/runs/bs621ja2</a><br> View project at: <a href='https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition' target="_blank">https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260616_092346-bs621ja2/logs</code>
# ✅ SmallCNN_Small_Batch_WD finished and logged

# %% [markdown]
# experiment 2.1: baseline overfittingს ვხედავთ

# %%
run_experiment(DeepCNN, "DeepCNN", "Baseline", lr=0.001, batch_size=64)
# Out:
# Tracking run with wandb version 0.27.2
# Run data is saved locally in <code>/content/wandb/run-20260616_092838-v60icihe</code>
# Syncing run <strong><a href='https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition/runs/v60icihe' target="_blank">DeepCNN_Baseline</a></strong> to <a href='https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition' target="_blank">https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition</a>
#  View run at <a href='https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition/runs/v60icihe' target="_blank">https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition/runs/v60icihe</a>
#  starting: DeepCNN | experiment: Baseline
# Configs: LR=0.001, Batch Size=64, Weight Decay=0.0
# Epoch 01 -> Train Loss: 1.6152, Train Acc: 36.24% | Val Loss: 1.4654, Val Acc: 43.14%
# Epoch 02 -> Train Loss: 1.3017, Train Acc: 50.23% | Val Loss: 1.2714, Val Acc: 51.06%
# Epoch 03 -> Train Loss: 1.0955, Train Acc: 58.58% | Val Loss: 1.2060, Val Acc: 55.35%
# Epoch 04 -> Train Loss: 0.8705, Train Acc: 67.61% | Val Loss: 1.2473, Val Acc: 55.49%
# Epoch 05 -> Train Loss: 0.5781, Train Acc: 78.71% | Val Loss: 1.4729, Val Acc: 55.57%
# Epoch 06 -> Train Loss: 0.3011, Train Acc: 89.51% | Val Loss: 1.8678, Val Acc: 55.87%
# Epoch 07 -> Train Loss: 0.1452, Train Acc: 95.31% | Val Loss: 2.3814, Val Acc: 54.65%
# Epoch 08 -> Train Loss: 0.1022, Train Acc: 97.18% | Val Loss: 2.7394, Val Acc: 55.35%
# Epoch 09 -> Train Loss: 0.0719, Train Acc: 98.11% | Val Loss: 3.0421, Val Acc: 55.78%
# Epoch 10 -> Train Loss: 0.0558, Train Acc: 98.64% | Val Loss: 3.1461, Val Acc: 54.88%
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>train_acc</td><td>▁▃▄▅▆▇████</td></tr><tr><td>train_loss</td><td>█▇▆▅▃▂▁▁▁▁</td></tr><tr><td>val_acc</td><td>▁▅████▇██▇</td></tr><tr><td>val_loss</td><td>▂▁▁▁▂▃▅▇██</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>train_acc</td><td>98.63718</td></tr><tr><td>train_loss</td><td>0.05581</td></tr><tr><td>val_acc</td><td>54.87635</td></tr><tr><td>val_loss</td><td>3.14612</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">DeepCNN_Baseline</strong> at: <a href='https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition/runs/v60icihe' target="_blank">https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition/runs/v60icihe</a><br> View project at: <a href='https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition' target="_blank">https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260616_092838-v60icihe/logs</code>
# ✅ DeepCNN_Baseline finished and logged

# %% [markdown]
# experiment

# %%
run_experiment(DeepCNN, "DeepCNN", "High_LR", lr=0.01, batch_size=64)
# Out:
# Tracking run with wandb version 0.27.2
# Run data is saved locally in <code>/content/wandb/run-20260616_093329-pg2qspnc</code>
# Syncing run <strong><a href='https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition/runs/pg2qspnc' target="_blank">DeepCNN_High_LR</a></strong> to <a href='https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition' target="_blank">https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition</a>
#  View run at <a href='https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition/runs/pg2qspnc' target="_blank">https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition/runs/pg2qspnc</a>
#  starting: DeepCNN | experiment: High_LR
# Configs: LR=0.01, Batch Size=64, Weight Decay=0.0
# Epoch 01 -> Train Loss: 2.1478, Train Acc: 24.54% | Val Loss: 1.8067, Val Acc: 25.55%
# Epoch 02 -> Train Loss: 1.8138, Train Acc: 25.03% | Val Loss: 1.8044, Val Acc: 25.55%
# Epoch 03 -> Train Loss: 1.8131, Train Acc: 25.03% | Val Loss: 1.8055, Val Acc: 25.55%
# Epoch 04 -> Train Loss: 1.8123, Train Acc: 25.03% | Val Loss: 1.8086, Val Acc: 25.55%
# Epoch 05 -> Train Loss: 1.8130, Train Acc: 25.03% | Val Loss: 1.8082, Val Acc: 25.55%
# Epoch 06 -> Train Loss: 1.8120, Train Acc: 25.03% | Val Loss: 1.8057, Val Acc: 25.55%
# Epoch 07 -> Train Loss: 1.8126, Train Acc: 25.03% | Val Loss: 1.8049, Val Acc: 25.55%
# Epoch 08 -> Train Loss: 1.8121, Train Acc: 25.03% | Val Loss: 1.8057, Val Acc: 25.55%
# Epoch 09 -> Train Loss: 1.8123, Train Acc: 25.03% | Val Loss: 1.8042, Val Acc: 25.55%
# Epoch 10 -> Train Loss: 1.8120, Train Acc: 25.03% | Val Loss: 1.8058, Val Acc: 25.55%
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>train_acc</td><td>▁█████████</td></tr><tr><td>train_loss</td><td>█▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_acc</td><td>▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>▅▁▃█▇▃▂▃▁▄</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>train_acc</td><td>25.02721</td></tr><tr><td>train_loss</td><td>1.812</td></tr><tr><td>val_acc</td><td>25.54859</td></tr><tr><td>val_loss</td><td>1.80585</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">DeepCNN_High_LR</strong> at: <a href='https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition/runs/pg2qspnc' target="_blank">https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition/runs/pg2qspnc</a><br> View project at: <a href='https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition' target="_blank">https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260616_093329-pg2qspnc/logs</code>
# ✅ DeepCNN_High_LR finished and logged

# %%
run_experiment(DeepCNN, "DeepCNN", "Small_Batch_WD", lr=0.001, batch_size=32, weight_decay=1e-4)
# Out:
# Tracking run with wandb version 0.27.2
# Run data is saved locally in <code>/content/wandb/run-20260616_093741-q14exoot</code>
# Syncing run <strong><a href='https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition/runs/q14exoot' target="_blank">DeepCNN_Small_Batch_WD</a></strong> to <a href='https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition' target="_blank">https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition</a>
#  View run at <a href='https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition/runs/q14exoot' target="_blank">https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition/runs/q14exoot</a>
#  starting: DeepCNN | experiment: Small_Batch_WD
# Configs: LR=0.001, Batch Size=32, Weight Decay=0.0001
# Epoch 01 -> Train Loss: 1.6226, Train Acc: 35.62% | Val Loss: 1.4458, Val Acc: 43.70%
# Epoch 02 -> Train Loss: 1.3292, Train Acc: 49.14% | Val Loss: 1.2819, Val Acc: 50.57%
# Epoch 03 -> Train Loss: 1.1591, Train Acc: 55.76% | Val Loss: 1.2504, Val Acc: 52.89%
# Epoch 04 -> Train Loss: 0.9883, Train Acc: 62.78% | Val Loss: 1.2587, Val Acc: 54.62%
# Epoch 05 -> Train Loss: 0.7764, Train Acc: 71.47% | Val Loss: 1.3578, Val Acc: 53.94%
# Epoch 06 -> Train Loss: 0.5321, Train Acc: 80.67% | Val Loss: 1.5633, Val Acc: 53.08%
# Epoch 07 -> Train Loss: 0.3274, Train Acc: 88.68% | Val Loss: 1.9401, Val Acc: 52.32%
# Epoch 08 -> Train Loss: 0.2095, Train Acc: 92.97% | Val Loss: 2.3701, Val Acc: 52.28%
# Epoch 09 -> Train Loss: 0.1559, Train Acc: 94.70% | Val Loss: 2.9086, Val Acc: 53.34%
# Epoch 10 -> Train Loss: 0.1366, Train Acc: 95.69% | Val Loss: 2.9264, Val Acc: 52.09%
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>train_acc</td><td>▁▃▃▄▅▆▇███</td></tr><tr><td>train_loss</td><td>█▇▆▅▄▃▂▁▁▁</td></tr><tr><td>val_acc</td><td>▁▅▇██▇▇▇▇▆</td></tr><tr><td>val_loss</td><td>▂▁▁▁▁▂▄▆██</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>train_acc</td><td>95.68947</td></tr><tr><td>train_loss</td><td>0.13664</td></tr><tr><td>val_acc</td><td>52.08986</td></tr><tr><td>val_loss</td><td>2.92636</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">DeepCNN_Small_Batch_WD</strong> at: <a href='https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition/runs/q14exoot' target="_blank">https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition/runs/q14exoot</a><br> View project at: <a href='https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition' target="_blank">https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260616_093741-q14exoot/logs</code>
# ✅ DeepCNN_Small_Batch_WD finished and logged

# %% [markdown]
# Experiment 3.1: baseline

# %%
run_experiment(OptCNN, "OptimalCNN", "Baseline", lr=0.001, batch_size=64)
# Out:
# Tracking run with wandb version 0.27.2
# Run data is saved locally in <code>/content/wandb/run-20260616_094336-j4v4cbwu</code>
# Syncing run <strong><a href='https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition/runs/j4v4cbwu' target="_blank">OptimalCNN_Baseline</a></strong> to <a href='https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition' target="_blank">https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition</a>
#  View run at <a href='https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition/runs/j4v4cbwu' target="_blank">https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition/runs/j4v4cbwu</a>
#  starting: OptimalCNN | experiment: Baseline
# Configs: LR=0.001, Batch Size=64, Weight Decay=0.0
# Epoch 01 -> Train Loss: 1.6198, Train Acc: 36.79% | Val Loss: 1.4260, Val Acc: 44.46%
# Epoch 02 -> Train Loss: 1.4111, Train Acc: 45.58% | Val Loss: 1.3382, Val Acc: 48.59%
# Epoch 03 -> Train Loss: 1.3379, Train Acc: 48.90% | Val Loss: 1.2701, Val Acc: 51.72%
# Epoch 04 -> Train Loss: 1.2878, Train Acc: 50.56% | Val Loss: 1.2291, Val Acc: 53.15%
# Epoch 05 -> Train Loss: 1.2503, Train Acc: 51.97% | Val Loss: 1.2062, Val Acc: 53.38%
# Epoch 06 -> Train Loss: 1.2066, Train Acc: 54.60% | Val Loss: 1.1694, Val Acc: 55.43%
# Epoch 07 -> Train Loss: 1.1804, Train Acc: 55.37% | Val Loss: 1.1503, Val Acc: 56.17%
# Epoch 08 -> Train Loss: 1.1587, Train Acc: 55.88% | Val Loss: 1.1324, Val Acc: 56.79%
# Epoch 09 -> Train Loss: 1.1214, Train Acc: 57.52% | Val Loss: 1.1162, Val Acc: 57.40%
# Epoch 10 -> Train Loss: 1.1058, Train Acc: 58.44% | Val Loss: 1.1276, Val Acc: 57.30%
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>train_acc</td><td>▁▄▅▅▆▇▇▇██</td></tr><tr><td>train_loss</td><td>█▅▄▃▃▂▂▂▁▁</td></tr><tr><td>val_acc</td><td>▁▃▅▆▆▇▇███</td></tr><tr><td>val_loss</td><td>█▆▄▄▃▂▂▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>train_acc</td><td>58.44037</td></tr><tr><td>train_loss</td><td>1.10585</td></tr><tr><td>val_acc</td><td>57.29711</td></tr><tr><td>val_loss</td><td>1.12762</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">OptimalCNN_Baseline</strong> at: <a href='https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition/runs/j4v4cbwu' target="_blank">https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition/runs/j4v4cbwu</a><br> View project at: <a href='https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition' target="_blank">https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260616_094336-j4v4cbwu/logs</code>
# ✅ OptimalCNN_Baseline finished and logged

# %% [markdown]
# experiment 3.2: opt cnn with high learning rate

# %%
run_experiment(OptCNN, "OptimalCNN", "High_LR", lr=0.01, batch_size=64)
# Out:
# Tracking run with wandb version 0.27.2
# Run data is saved locally in <code>/content/wandb/run-20260616_094637-permdkhn</code>
# Syncing run <strong><a href='https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition/runs/permdkhn' target="_blank">OptimalCNN_High_LR</a></strong> to <a href='https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition' target="_blank">https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition</a>
#  View run at <a href='https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition/runs/permdkhn' target="_blank">https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition/runs/permdkhn</a>
#  starting: OptimalCNN | experiment: High_LR
# Configs: LR=0.01, Batch Size=64, Weight Decay=0.0
# Epoch 01 -> Train Loss: 1.6520, Train Acc: 35.80% | Val Loss: 1.4666, Val Acc: 42.49%
# Epoch 02 -> Train Loss: 1.4207, Train Acc: 45.03% | Val Loss: 1.3386, Val Acc: 48.97%
# Epoch 03 -> Train Loss: 1.3493, Train Acc: 48.03% | Val Loss: 1.3407, Val Acc: 48.85%
# Epoch 04 -> Train Loss: 1.2914, Train Acc: 50.64% | Val Loss: 1.2545, Val Acc: 52.53%
# Epoch 05 -> Train Loss: 1.2580, Train Acc: 52.07% | Val Loss: 1.1894, Val Acc: 55.00%
# Epoch 06 -> Train Loss: 1.2226, Train Acc: 53.39% | Val Loss: 1.1860, Val Acc: 54.82%
# Epoch 07 -> Train Loss: 1.1948, Train Acc: 54.45% | Val Loss: 1.1513, Val Acc: 56.27%
# Epoch 08 -> Train Loss: 1.1791, Train Acc: 55.38% | Val Loss: 1.1330, Val Acc: 57.44%
# Epoch 09 -> Train Loss: 1.1440, Train Acc: 56.51% | Val Loss: 1.1638, Val Acc: 55.76%
# Epoch 10 -> Train Loss: 1.1309, Train Acc: 56.95% | Val Loss: 1.1049, Val Acc: 57.75%
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>train_acc</td><td>▁▄▅▆▆▇▇▇██</td></tr><tr><td>train_loss</td><td>█▅▄▃▃▂▂▂▁▁</td></tr><tr><td>val_acc</td><td>▁▄▄▆▇▇▇█▇█</td></tr><tr><td>val_loss</td><td>█▆▆▄▃▃▂▂▂▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>train_acc</td><td>56.94692</td></tr><tr><td>train_loss</td><td>1.13085</td></tr><tr><td>val_acc</td><td>57.74991</td></tr><tr><td>val_loss</td><td>1.10486</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">OptimalCNN_High_LR</strong> at: <a href='https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition/runs/permdkhn' target="_blank">https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition/runs/permdkhn</a><br> View project at: <a href='https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition' target="_blank">https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260616_094637-permdkhn/logs</code>
# ✅ OptimalCNN_High_LR finished and logged

# %% [markdown]
# experiment3.3 : opt snn with small batch and regularization

# %%
run_experiment(OptCNN, "OptimalCNN", "Small_Batch_WD", lr=0.001, batch_size=32, weight_decay=1e-4)
# Out:
# Tracking run with wandb version 0.27.2
# Run data is saved locally in <code>/content/wandb/run-20260616_094940-k16e5i1j</code>
# Syncing run <strong><a href='https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition/runs/k16e5i1j' target="_blank">OptimalCNN_Small_Batch_WD</a></strong> to <a href='https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition' target="_blank">https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition</a>
#  View run at <a href='https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition/runs/k16e5i1j' target="_blank">https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition/runs/k16e5i1j</a>
#  starting: OptimalCNN | experiment: Small_Batch_WD
# Configs: LR=0.001, Batch Size=32, Weight Decay=0.0001
# Epoch 01 -> Train Loss: 1.5832, Train Acc: 38.16% | Val Loss: 1.3722, Val Acc: 47.06%
# Epoch 02 -> Train Loss: 1.3987, Train Acc: 46.65% | Val Loss: 1.2751, Val Acc: 51.83%
# Epoch 03 -> Train Loss: 1.3261, Train Acc: 49.30% | Val Loss: 1.2521, Val Acc: 51.45%
# Epoch 04 -> Train Loss: 1.2850, Train Acc: 50.79% | Val Loss: 1.2170, Val Acc: 53.48%
# Epoch 05 -> Train Loss: 1.2464, Train Acc: 52.86% | Val Loss: 1.1799, Val Acc: 54.77%
# Epoch 06 -> Train Loss: 1.2101, Train Acc: 53.99% | Val Loss: 1.1646, Val Acc: 55.82%
# Epoch 07 -> Train Loss: 1.1866, Train Acc: 55.49% | Val Loss: 1.1427, Val Acc: 56.70%
# Epoch 08 -> Train Loss: 1.1538, Train Acc: 56.20% | Val Loss: 1.1365, Val Acc: 57.23%
# Epoch 09 -> Train Loss: 1.1287, Train Acc: 57.16% | Val Loss: 1.1114, Val Acc: 57.68%
# Epoch 10 -> Train Loss: 1.1123, Train Acc: 57.88% | Val Loss: 1.0987, Val Acc: 58.73%
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>train_acc</td><td>▁▄▅▅▆▇▇▇██</td></tr><tr><td>train_loss</td><td>█▅▄▄▃▂▂▂▁▁</td></tr><tr><td>val_acc</td><td>▁▄▄▅▆▆▇▇▇█</td></tr><tr><td>val_loss</td><td>█▆▅▄▃▃▂▂▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>train_acc</td><td>57.88305</td></tr><tr><td>train_loss</td><td>1.11229</td></tr><tr><td>val_acc</td><td>58.72518</td></tr><tr><td>val_loss</td><td>1.09872</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">OptimalCNN_Small_Batch_WD</strong> at: <a href='https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition/runs/k16e5i1j' target="_blank">https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition/runs/k16e5i1j</a><br> View project at: <a href='https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition' target="_blank">https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260616_094940-k16e5i1j/logs</code>
# ✅ OptimalCNN_Small_Batch_WD finished and logged

# %%
import torchvision.transforms as transforms
from torch.utils.data import DataLoader


train_transform = transforms.Compose([
    transforms.ToPILImage(),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(15),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5], std=[0.5])
])


val_transform = transforms.Compose([
    transforms.ToPILImage(),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5], std=[0.5])
])

class AdvancedFERDataset(Dataset):
    def __init__(self, df, transform=None):
        self.df = df
        self.transform = transform

    def __len__(self): return len(self.df)

    def __getitem__(self, idx):
        row = self.df.iloc[idx]
        pixels = np.fromstring(row['pixels'], dtype=np.uint8, sep=' ')
        image = pixels.reshape(48, 48)
        label = int(row['emotion'])
        if self.transform: image = self.transform(image)
        return image, label


indices = list(range(len(train_df)))
split = int(0.8 * len(train_df))
train_indices, val_indices = indices[:split], indices[split:]

train_set = AdvancedFERDataset(train_df.iloc[train_indices], transform=train_transform)
val_set = AdvancedFERDataset(train_df.iloc[val_indices], transform=val_transform)

print("this is ready")
# Out:
# this is ready

# %%
import torch.nn as nn

class ResidualBlock(nn.Module):
    def __init__(self, in_channels, out_channels, stride=1):
        super().__init__()
        self.conv1 = nn.Conv2d(in_channels, out_channels, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(out_channels)
        self.relu = nn.ReLU()
        self.conv2 = nn.Conv2d(out_channels, out_channels, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(out_channels)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_channels != out_channels:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_channels, out_channels, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(out_channels)
            )

    def forward(self, x):
        out = self.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x)
        out = self.relu(out)
        return out

class FaceResNet(nn.Module):
    def __init__(self):
        super().__init__()
        self.in_channels = 32

        self.init_conv = nn.Sequential(
            nn.Conv2d(1, 32, kernel_size=3, stride=1, padding=1, bias=False),
            nn.BatchNorm2d(32),
            nn.ReLU()
        )


        self.layer1 = ResidualBlock(32, 64, stride=2)  # 48x48 -> 24x24
        self.layer2 = ResidualBlock(64, 128, stride=2) # 24x24 -> 12x12
        self.layer3 = ResidualBlock(128, 256, stride=2) # 12x12 -> 6x6

        self.avg_pool = nn.AdaptiveAvgPool2d((1, 1))
        self.classifier = nn.Sequential(
            nn.Flatten(),
            nn.Dropout(0.5),
            nn.Linear(256, 7)
        )

    def forward(self, x):
        out = self.init_conv(x)
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.avg_pool(out)
        out = self.classifier(out)
        return out

print("model ready")
# Out:
# model ready

# %%
def run_advanced_experiment(model_class, model_name, exp_name, epochs=30, lr=0.001, batch_size=64):
    wandb.init(
        project="facial-expression-recognition",
        name=f"{model_name}_{exp_name}",
        config={
            "model_architecture": model_name,
            "experiment_type": exp_name,
            "learning_rate": lr,
            "batch_size": batch_size,
            "epochs": epochs,
            "augmented_data": True
        }
    )

    train_loader = DataLoader(train_set, batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(val_set, batch_size=batch_size, shuffle=False)

    model = model_class().to(device)
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=1e-4)
    scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', patience=3, factor=0.5)

    print(f"\n start training : {model_name} ({epochs} epoch")

    for epoch in range(epochs):
        # treining
        model.train()
        running_loss, correct, total = 0.0, 0, 0
        for images, labels in train_loader:
            images, labels = images.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item() * images.size(0)
            _, predicted = outputs.max(1)
            total += labels.size(0)
            correct += predicted.eq(labels).sum().item()

        train_loss = running_loss / len(train_set)
        train_acc = 100.0 * correct / total

        # validation
        model.eval()
        val_loss, val_correct, val_total = 0.0, 0, 0
        with torch.no_grad():
            for images, labels in val_loader:
                images, labels = images.to(device), labels.to(device)
                outputs = model(images)
                loss = criterion(outputs, labels)

                val_loss += loss.item() * images.size(0)
                _, predicted = outputs.max(1)
                val_total += labels.size(0)
                val_correct += predicted.eq(labels).sum().item()

        valid_loss = val_loss / len(val_set)
        val_acc = 100.0 * val_correct / val_total

        # validation
        scheduler.step(valid_loss)

        print(f"Epoch {epoch+1:02d}/{epochs} -> Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.2f}% | Val Loss: {valid_loss:.4f}, Val Acc: {val_acc:.2f}%")

        wandb.log({
            "epoch": epoch + 1,
            "train_loss": train_loss,
            "train_acc": train_acc,
            "val_loss": valid_loss,
            "val_acc": val_acc,
            "lr": optimizer.param_groups[0]['lr']
        })

    wandb.finish()
    print(f" {model_name}_{exp_name} finished and logged")

# %%
run_advanced_experiment(FaceResNet, "FaceResNet", "Augmented_30Epochs", epochs=30, lr=0.001, batch_size=64)
# Out:
# Finishing previous runs because reinit is set to 'default'.
#  View run <strong style="color:#cdcd00">FaceResNet_Augmented_30Epochs</strong> at: <a href='https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition/runs/59g70e8n' target="_blank">https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition/runs/59g70e8n</a><br> View project at: <a href='https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition' target="_blank">https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260616_100236-59g70e8n/logs</code>
# Tracking run with wandb version 0.27.2
# Run data is saved locally in <code>/content/wandb/run-20260616_100340-2c67yeku</code>
# Syncing run <strong><a href='https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition/runs/2c67yeku' target="_blank">FaceResNet_Augmented_30Epochs</a></strong> to <a href='https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition' target="_blank">https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition</a>
#  View run at <a href='https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition/runs/2c67yeku' target="_blank">https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition/runs/2c67yeku</a>
#  start training : FaceResNet (30 epoch
# Epoch 01/30 -> Train Loss: 1.7207, Train Acc: 29.95% | Val Loss: 1.5343, Val Acc: 41.43%
# Epoch 02/30 -> Train Loss: 1.4381, Train Acc: 44.59% | Val Loss: 1.3835, Val Acc: 48.17%
# Epoch 03/30 -> Train Loss: 1.3260, Train Acc: 49.21% | Val Loss: 1.2345, Val Acc: 53.45%
# Epoch 04/30 -> Train Loss: 1.2623, Train Acc: 51.63% | Val Loss: 1.2651, Val Acc: 51.46%
# Epoch 05/30 -> Train Loss: 1.2162, Train Acc: 54.10% | Val Loss: 1.1760, Val Acc: 55.31%
# Epoch 06/30 -> Train Loss: 1.1808, Train Acc: 55.14% | Val Loss: 1.1423, Val Acc: 55.87%
# Epoch 07/30 -> Train Loss: 1.1489, Train Acc: 56.57% | Val Loss: 1.1493, Val Acc: 56.74%
# Epoch 08/30 -> Train Loss: 1.1153, Train Acc: 57.85% | Val Loss: 1.0927, Val Acc: 57.73%
# Epoch 09/30 -> Train Loss: 1.0942, Train Acc: 58.54% | Val Loss: 1.0646, Val Acc: 60.15%
# Epoch 10/30 -> Train Loss: 1.0754, Train Acc: 59.64% | Val Loss: 1.0767, Val Acc: 59.58%
# Epoch 11/30 -> Train Loss: 1.0517, Train Acc: 60.20% | Val Loss: 1.0622, Val Acc: 59.56%
# Epoch 12/30 -> Train Loss: 1.0379, Train Acc: 60.53% | Val Loss: 1.0452, Val Acc: 61.09%
# Epoch 13/30 -> Train Loss: 1.0120, Train Acc: 62.01% | Val Loss: 1.0091, Val Acc: 62.63%
# Epoch 14/30 -> Train Loss: 0.9975, Train Acc: 62.51% | Val Loss: 1.0434, Val Acc: 60.99%
# Epoch 15/30 -> Train Loss: 0.9769, Train Acc: 63.29% | Val Loss: 1.0417, Val Acc: 60.78%
# Epoch 16/30 -> Train Loss: 0.9600, Train Acc: 63.97% | Val Loss: 0.9983, Val Acc: 62.30%
# Epoch 17/30 -> Train Loss: 0.9454, Train Acc: 64.24% | Val Loss: 1.0853, Val Acc: 59.61%
# Epoch 18/30 -> Train Loss: 0.9293, Train Acc: 65.37% | Val Loss: 1.0177, Val Acc: 62.70%
# Epoch 19/30 -> Train Loss: 0.9089, Train Acc: 65.77% | Val Loss: 1.0071, Val Acc: 62.92%
# Epoch 20/30 -> Train Loss: 0.9031, Train Acc: 66.26% | Val Loss: 1.0546, Val Acc: 61.48%
# Epoch 21/30 -> Train Loss: 0.8208, Train Acc: 69.43% | Val Loss: 0.9803, Val Acc: 64.65%
# Epoch 22/30 -> Train Loss: 0.7837, Train Acc: 71.02% | Val Loss: 0.9777, Val Acc: 64.99%
# Epoch 23/30 -> Train Loss: 0.7687, Train Acc: 71.39% | Val Loss: 1.0126, Val Acc: 63.31%
# Epoch 24/30 -> Train Loss: 0.7395, Train Acc: 72.53% | Val Loss: 1.0054, Val Acc: 64.35%
# Epoch 25/30 -> Train Loss: 0.7334, Train Acc: 72.98% | Val Loss: 0.9999, Val Acc: 64.70%
# Epoch 26/30 -> Train Loss: 0.7059, Train Acc: 73.87% | Val Loss: 1.0977, Val Acc: 62.21%
# Epoch 27/30 -> Train Loss: 0.6454, Train Acc: 76.60% | Val Loss: 1.0261, Val Acc: 64.14%
# Epoch 28/30 -> Train Loss: 0.6133, Train Acc: 77.35% | Val Loss: 1.0344, Val Acc: 64.25%
# Epoch 29/30 -> Train Loss: 0.5965, Train Acc: 78.13% | Val Loss: 1.0581, Val Acc: 63.74%
# Epoch 30/30 -> Train Loss: 0.5813, Train Acc: 78.82% | Val Loss: 1.0881, Val Acc: 64.35%
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▂▂▂▂▃▃▃▃▄▄▄▄▅▅▅▅▆▆▆▆▇▇▇▇███</td></tr><tr><td>lr</td><td>███████████████████▄▄▄▄▄▄▂▂▂▂▁</td></tr><tr><td>train_acc</td><td>▁▃▄▄▄▅▅▅▅▅▅▅▆▆▆▆▆▆▆▆▇▇▇▇▇▇████</td></tr><tr><td>train_loss</td><td>█▆▆▅▅▅▄▄▄▄▄▄▄▄▃▃▃▃▃▃▂▂▂▂▂▂▁▁▁▁</td></tr><tr><td>val_acc</td><td>▁▃▅▄▅▅▆▆▇▆▆▇▇▇▇▇▆▇▇▇██▇██▇████</td></tr><tr><td>val_loss</td><td>█▆▄▅▃▃▃▂▂▂▂▂▁▂▂▁▂▂▁▂▁▁▁▁▁▃▂▂▂▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>30</td></tr><tr><td>lr</td><td>0.00013</td></tr><tr><td>train_acc</td><td>78.82179</td></tr><tr><td>train_loss</td><td>0.58135</td></tr><tr><td>val_acc</td><td>64.3504</td></tr><tr><td>val_loss</td><td>1.0881</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">FaceResNet_Augmented_30Epochs</strong> at: <a href='https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition/runs/2c67yeku' target="_blank">https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition/runs/2c67yeku</a><br> View project at: <a href='https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition' target="_blank">https://wandb.ai/mkapa22-free-university-of-tbilisi-/facial-expression-recognition</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260616_100340-2c67yeku/logs</code>
#  FaceResNet_Augmented_30Epochs finished and logged
